# %%
import pandas as pd

# %%
recepten =pd.read_csv('data_nutritions.csv')
recepten['energie'] = (recepten['nutrition'] == 'energie').astype(int)
recepten['koolhydraten'] = (recepten['nutrition'] == 'koolhydraten').astype(int)
recepten['waarvan suikers'] = (recepten['nutrition'] == 'waarvan suikers').astype(int)
recepten['natrium'] = (recepten['nutrition'] == 'natrium').astype(int)
recepten['eiwit'] = (recepten['nutrition'] == 'eiwit').astype(int)
recepten['vet'] = (recepten['nutrition'] == 'vet').astype(int)
recepten['waarvan verzadigd'] = (recepten['nutrition'] == 'waarvan verzadigd').astype(int)
recepten['vezels'] = (recepten['nutrition'] == 'vezels').astype(int)
recepten
# Out:
#        Unnamed: 0                            recipe          nutrition  \
# 0               0     Kruidnoten met choco-discodip            energie
# 1               1     Kruidnoten met choco-discodip       koolhydraten
# 2               2     Kruidnoten met choco-discodip    waarvan suikers
# 3               3     Kruidnoten met choco-discodip            natrium
# 4               4     Kruidnoten met choco-discodip              eiwit
# ...           ...                               ...                ...
# 40911       58755   Ceviche met sint-jakobsschelpen  waarvan verzadigd
# 40912       58761  Biefstuk met rodewijnsaus en ham            energie
# 40913       58762  Biefstuk met rodewijnsaus en ham       koolhydraten
# 40914       58763  Biefstuk met rodewijnsaus en ham              eiwit
# 40915       58764  Biefstuk met rodewijnsaus en ham                vet
#
#           value  energie  koolhydraten  waarvan suikers  natrium  eiwit  vet  \
# ...
