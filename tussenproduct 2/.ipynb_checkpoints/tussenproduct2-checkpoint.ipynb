# %% [markdown]
# # Tussenproduct 2 : statistische analyses op de receptendata
# ## De Haagse Hogeschool
# ## Toegepaste Wiskunde
#
#
# Groep 3
# Fenne van Agthoven, Phealana Fiamingo, Araksan Hassan en Kika van Vliet
# Datum: 3 mei 2024

# %% [markdown]
# ## Klasse structuur die de recept data bevat en de onderstaande functies
#     - Een method die de tabel met de ingrediënten inlaadt en die als property bewaard. Je moet zowel de originele als de schoongemaakte data in kunnen laden.
#     - Een property die aangeeft of de ingeladen data schoongemaakt is.
#     - Een method die recepten aanbeveelt op basis van een lijstje favoriete recepten. Voeg hiervoor alle ingrediënten in het lijstje met favoriete recepten samen in een vector, en bereken de cosinusgelijkenis tussen deze vector en de ingrediëntenvectoren van elk ander recept. Raadt de recepten aan waarvan de ingrediënten de grootste overeenkomst hebben met de ingrediënten van de favoriete recepten. Deze functie gebruiken we later om het weekmenu samen te stellen.

# %%
import pandas as pd 
import numpy as np
from numpy.linalg import norm
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import statsmodels.formula.api as smf

ingr_ns=pd.read_csv('tabellen/data_ingr.csv')
ingr_schoon=pd.read_csv('tabellen/data_ingr_clean.csv') 
recipes = pd.read_csv('tabellen/Recepten_kiezen_gescheiden.csv') # Onze lijst van recepten die we wel en niet lekker vinden
recipes_wel = recipes[:80] # DataFrame met alle recpeten die wij lekker vinden
recipes_niet = recipes[80:] # DataFrame met alle recepten die wij niet lekker vinden

# %%
class Recepten: 
    
    def __init__(self, data_ingr, schoongemaakt=False): 
        # Initialisatie van de klasse met het pad naar de data en of de data schoon is 
        self.data_ingr = data_ingr
        self.schoongemaakt = schoongemaakt
        
    def laad_ingr(self):
        # Methode die de ingrediëntentabel inlaadt
        self.tabel = pd.read_csv(self.data_ingr)
        
    def aanbeveling(self, fav_recepten):
        # Alle favoriete ingredienten worden gezocht, dmv set worden de duplicates weggehaald
        self.fav_ingr = list(set(self.tabel['ingredient'].loc[self.tabel['recipe'].isin(fav_recepten)]))
        # Initialisatie van de CountVectorizer die text data convergeert naar getallen
        count_vectorizer = CountVectorizer()
        # Convergeert fav_ingr naar een matrix van tokens
        self.fav_matrix = count_vectorizer.fit_transform(self.fav_ingr)
        # Initialiseer een lege lijst om alle recepten op te slaan
        titel_lijst = []
        # Itereer door alle recepten, maar filter de favoriete eruit en voorkom ook dubbele receptnamen
        [titel_lijst.append(recept) for recept in self.tabel['recipe'] if recept not in fav_recepten and recept not in titel_lijst]
        # Initialiseer een lege lijst om de gelijkenisscore in te bewaren tussen de fav recepten en alle andere
        gelijkenis = []
        # Bereken de cosinusgelijkenis tussen de fav recepten en alle ander
        for recept in titel_lijst:
            # Kies de ingredientelijst van het huidige recept
            recept_lijst = list(self.tabel['ingredient'].loc[self.tabel['recipe']==recept])
            # Convergeer de ingredientenlijst naar een matrix van token obv de fav_matrix
            rec_matrix = count_vectorizer.transform(recept_lijst)
            # Bereken de cosinusgelijkenis tussen het huidige recept en de favoriete ingredienten, 
            # dmv van een vector bestaand uit enen, evengroot als het aantal ingredienten in het huidige recept
            cosinus = cosine_similarity(np.ones(np.size(rec_matrix.toarray())).reshape(1,-1), rec_matrix.reshape(1,-1))
            # Voeg de gelijkenis score en het recept toe aan de lijst
            gelijkenis.append([cosinus[0][0],recept])
        
        # Sorteer de lijst aan gelijkenissen op aflopende volgorde
        gelijkenis.sort(reverse=True)
        # Selecteer de top 10 aanbevolen recepten op basis van de cosinusgelijkenis
        self.aanbeveling = [titel[1] for titel in gelijkenis][:10]
        
        return self.aanbeveling
        
recepten_klasse = Recepten('tabellen/data_ingr_clean.csv',schoongemaakt=True)
recepten_klasse.laad_ingr()

# %% [markdown]
# ## Evaluatie van het aanbevelingsalgoritme met de Precision@10 metriek.
# We hebben de aanbevelingsfunctie gebruikt om per groepslid 10 recepten aan te raden op basis van onze favoriete recepten.
# Om te evalueren of de aanbevelingsfunctie goed werkt hebben we de Precision@10 metriek berekend.
# We hebben dit eerst gedaan met de schoongemaakte dataset en vervolgens ook met de orginele dataset.

# %% [markdown]
# ### De Precision@10 metriek met de schoongemaakte dataset

# %% [markdown]
# **Kika**
# Uit de 10 aanbevolen recepten voor Kika, zou zij zelf 8 recepten maken.
# De Precision@10 is dan: 8/10 = 0.8

# %%
recepten_kika = recipes_wel[:20]
recepten_klasse_k = Recepten('tabellen/data_ingr_clean.csv',schoongemaakt=True)
recepten_klasse_k.laad_ingr()
fav_recepten_k = recepten_kika['title'].tolist()
aanbevolen_k = recepten_klasse_k.aanbeveling(fav_recepten_k)
print('De volgende 10 recepten worden aanbevolen voor Kika: ', aanbevolen_k)
# Out:
# De volgende 10 recepten worden aanbevolen voor Kika:  ['Snelle Thaise viskoekjes met chilisaus', "Volkorenpincho's", 'Asperges koken', 'Snelle noedelroerbak met groene currypasta en een eitje', 'Mexicaanse maaltijdsoep van zoete aardappel met kidneybonen ', 'Yoghurtmarinade met baharat', 'Zoete aardappel uit de airfryer', 'Kruidendip', 'Kaasvlinders', 'Pittige zoete-aardappelspread']

# %% [markdown]
# **Araksan**
# Uit de 10 aanbevolen recepten voor Araksan, zou zij zelf 8 recepten maken.
# De Precision@10 is dan: 8/10 = 0.8

# %%
recepten_araksan = recipes_wel[20:40]
recepten_klasse_a = Recepten('tabellen/data_ingr_clean.csv',schoongemaakt=True)
recepten_klasse_a.laad_ingr()
fav_recepten_a = recepten_araksan['title'].tolist()
aanbevolen_a = recepten_klasse_a.aanbeveling(fav_recepten_a)
print('De volgende 10 recepten worden aanbevolen voor Araksan: ', aanbevolen_a)
# Out:
# De volgende 10 recepten worden aanbevolen voor Araksan:  ['Kerstballetjes met gesmolten kaas', "Burrito'-schotel met knapperige tortillapuntjes", 'Mexicaanse maaltijdsoep van zoete aardappel met kidneybonen ', 'Frisse yoghurtsaus met gegrilde paprika', 'Gepofte aardappel met tonijn', 'Traybake met kikkererwten, kipgehaktballetjes en garam masala', 'Aardappel-tonijnsalade met asperges', 'Homemade tomatensaus', 'Pastasalade met mais &amp; paprika', 'Mexicaanse tonijnwraps']

# %% [markdown]
# **Fenne**
# Uit de 10 aanbevolen recepten voor Fenne, zou zij zelf 7 recepten maken.
# De Precision@10 is dan: 7/10 = 0.7

# %%
recepten_fenne = recipes_wel[40:60]
recepten_klasse_f = Recepten('tabellen/data_ingr_clean.csv',schoongemaakt=True)
recepten_klasse_f.laad_ingr()
fav_recepten_f = recepten_fenne['title'].tolist()
aanbevolen_f = recepten_klasse_f.aanbeveling(fav_recepten_f)
print('De volgende 10 recepten worden aanbevolen voor Fenne: ', aanbevolen_f)

# %% [markdown]
# **Phealana**
# Uit de 10 aanbevolen recepten voor Phealana, zou zij zelf 8 recepten maken.
# De Precision@10 is dan: 8/10 = 0.8

# %%
recepten_phea = recipes_wel[60:80]
recepten_klasse_p = Recepten('tabellen/data_ingr_clean.csv',schoongemaakt=True)
recepten_klasse_p.laad_ingr()
fav_recepten_p = recepten_phea['title'].tolist()
aanbevolen_p = recepten_klasse_p.aanbeveling(fav_recepten_p)
print('De volgende 10 recepten worden aanbevolen voor Phea: ', aanbevolen_p)

# %% [markdown]
# **Uitkomst:**
# De gemiddelde Precision@10 voor de schoongemaakte dataset is ongeveer 0.8.
# Wij zijn tevreden met deze uitkomst, hiermee kunnen we stellen dat onze aanbevelingsfunctie goed werkt.

# %% [markdown]
# ### De Precision@10 metriek met de orginele dataset

# %% [markdown]
# **Kika**
# Uit de 10 aanbevolen recepten voor Kika, zou zij zelf 7 recepten maken.
# De Precision@10 is dan: 7/10 = 0.7

# %%
recepten_klasse_k = Recepten('tabellen/data_ingr.csv',schoongemaakt=False)
recepten_klasse_k.laad_ingr()
fav_recepten_k = recepten_kika['title'].tolist()
aanbevolen_k = recepten_klasse_k.aanbeveling(fav_recepten_k)
print('De volgende 10 recepten worden aanbevolen voor Kika: ', aanbevolen_k)
# precision@10: 7/10= 70%

# %% [markdown]
# **Araksan**
# Uit de 10 aanbevolen recepten voor Araksan, zou zij zelf 6 recepten maken.
# De Precision@10 is dan: 6/10 = 0.6

# %%
recepten_klasse_a = Recepten('tabellen/data_ingr.csv',schoongemaakt=False)
recepten_klasse_a.laad_ingr()
fav_recepten_a = recepten_araksan['title'].tolist()
aanbevolen_a = recepten_klasse_a.aanbeveling(fav_recepten_a)
print('De volgende 10 recepten worden aanbevolen voor Araksan: ', aanbevolen_a)
# precision@10: 6/10= 60%

# %% [markdown]
# **Fenne**
# Uit de 10 aanbevolen recepten voor Fenne, zou zij zelf 7 recepten maken.
# De Precision@10 is dan: 7/10 = 0.7

# %%
recepten_klasse_f = Recepten('tabellen/data_ingr.csv',schoongemaakt=False)
recepten_klasse_f.laad_ingr()
fav_recepten_f = recepten_fenne['title'].tolist()
aanbevolen_f = recepten_klasse_f.aanbeveling(fav_recepten_f)
print('De volgende 10 recepten worden aanbevolen voor Fenne: ', aanbevolen_f)
# precision@10: 7/10= 70%

# %% [markdown]
# **Phealana**
# Uit de 10 aanbevolen recepten voor Phealana, zou zij zelf 6 recepten maken.
# De Precision@10 is dan: 6/10 = 0.6

# %%
recepten_klasse_p = Recepten('tabellen/data_ingr.csv',schoongemaakt=False)
recepten_klasse_p.laad_ingr()
fav_recepten_p = recepten_phea['title'].tolist()
aanbevolen_p = recepten_klasse_p.aanbeveling(fav_recepten_p)
print('De volgende 10 recepten worden aanbevolen voor Phea: ', aanbevolen_p)
# precision@10: 6/10= 60%

# %% [markdown]
# **Uitkomst:**
# De gemiddelde Precision@10 voor de orginele dataset is 0.65.
# Deze uitkomst is lager dan bij de schoongemaakte dataset.
# We kunnen stellen dat het nuttig was om de dataset op te schonen, omdat de aanbevelingsfunctie dan beter werkt volgens de Precision@10 metriek.

# %% [markdown]
# ## Dataverkenning
#
# In tussenproduct één hebben we de data grondig gereinigd. Echter, bestaat de mogelijkheid dat er nog steeds fouten in de data zitten. Om de betrouwbaarheid te waarborgen voordat we verdergaan met de analyse, is het belangrijk dat we vertrouwen hebben in de data, vooral de variabelen die we van plan zijn te gebruiken (extra eis).
#
# Het is belangrijk om te controleren dat er geen fouten aanwezig zijn in de dataset. Dit kan worden gedaan door verschillende methoden, waaronder visualisaties.
#
# We hebben daarom de volgende stappen ondernomen:

# %% [markdown]
# **Stap 1:** Eerst hebben we gekeken of alle recepten wel echt in beide datasets voorkwamen. Dit was nodig om goed alle hoeveelheiden om te zetten naar hoveelheden per persoon.

# %%
import pandas as pd  #inladen bibliotheken
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from scipy.stats import ttest_ind

ingr_schoon=pd.read_csv('tabellen/data_ingr_clean.csv')  
recepten=pd.read_csv('tabellen/data_recipes.csv') 
niet_erin = ingr_schoon[~ingr_schoon['recipe'].isin(recepten['title'])]
i = niet_erin.index
ingr_schoon.drop(i,inplace=True)

# %% [markdown]
# **Stap 2:** Vervolgens hebben we de hoeveelheid per persoon berekend.
# Dit hebben we gedaan door eerst de dataframe met alle recepten, waar ook het aantal personen in zit, te mergen met de dataframe met alle ingrediënten.
# Vervolgens hebben we een kolom toegevoegd die de hoeveelheid per persoon bevat. Dit is berekend door de hoeveelheid te delen door het aantal personen.
# Uiteindelijk hebben we nog kolommen verwijderd om een overzichtelijke dataframe te krijgen.

# %%
ingr_pp = ingr_schoon.copy().merge(recepten[['title', 'persons']], left_on='recipe', right_on='title')
ingr_pp['hoeveelheid_pp'] = ingr_pp['quantity'] / ingr_pp['persons']
ingr_pp.drop(columns=['title','persons', 'Unnamed: 0','quantity'], inplace=True)
ingr_pp = ingr_pp[['recipe','ingredient','hoeveelheid_pp','unit']]
ingr_pp
# Out:
#                                  recipe            ingredient  hoeveelheid_pp  \
# 0         Kruidnoten met choco-discodip         melkchocolade           25.00
# 1         Kruidnoten met choco-discodip            kruidnoten           25.00
# 2         Kruidnoten met choco-discodip              discodip            5.00
# 3               Kruidnoten in marsepein       blankemarsepein           37.50
# 4               Kruidnoten in marsepein  ongezouten roomboter            3.75
# ...                                 ...                   ...             ...
# 49604  Biefstuk met rodewijnsaus en ham             olijfolie            4.00
# 49605  Biefstuk met rodewijnsaus en ham           biefstukken          250.00
# 49606  Biefstuk met rodewijnsaus en ham                 boter          250.00
# 49607  Biefstuk met rodewijnsaus en ham            serranoham           10.00
# 49608  Biefstuk met rodewijnsaus en ham             rode wijn           50.00
#
#       unit
# 0        g
# 1        g
# 2        g
# 3        g
# 4        g
# ...    ...
# 49604    g
# 49605    g
# 49606    g
# 49607    g
# 49608    g
#
# [49609 rows x 4 columns]

# %% [markdown]
# **Stap 3:** We hebben een boxplot gemaakt van alle hoeveelheden om te kijken of er uitbijters zijn.

# %%
plt.figure(figsize=(15,4))
sns.boxplot(x=ingr_pp['hoeveelheid_pp'])
plt.title('Boxplot van hoeveelheden')
plt.xlabel('hoeveelheid in gram')
plt.grid()
plt.show()

# %% [markdown]
# **Stap 4:** Vervolgens hebben we alle ingredienten geselecteerd waarbij de hoeveelheid groter is dan 800 gram. Wij hebben hiervoor gekozen omdat we dat een normale hoeveelheid gram vinden voor 1 persoon.
# We hebben dit gevisualiseerd door middel van een scatterplot.

# %%
gr_dan =  ingr_pp.copy()[(ingr_pp['hoeveelheid_pp'] > 800)]
plt.figure(figsize=(6,12))
plt.scatter(gr_dan['hoeveelheid_pp'], gr_dan['ingredient'])
plt.grid()
plt.title('Scatterplot van de ingredienten die meer dan 800 gram zijn')
plt.xlabel('hoeveelheid in gram')
plt.show()

# %% [markdown]
# **Stap 5:** We vervangen alle ingrediënten die groter dan 800 gram zijn door de mediaan van het ingrediënt.
# Vervolgens vervangen we de hoeveelheden in de dataset en visualiseren we de hoeveelheden met een boxplot om te kijken of alle uitbijters verwijderd zijn.

# %%
for i in gr_dan['ingredient']:   
    median_i = ingr_pp['hoeveelheid_pp'].loc[ingr_pp['ingredient']== i].median() #De hoeveelheden van ingredienten > 10k overzetten naar mediaan van ingredient
    gr_dan['hoeveelheid_pp'].mask(gr_dan['ingredient'] == i, median_i, inplace=True)
    
for i in gr_dan['ingredient']:
    quantity_i = gr_dan['hoeveelheid_pp'].loc[gr_dan['ingredient']== i]
    ingr_pp['hoeveelheid_pp'].mask(ingr_pp['ingredient'] == i, quantity_i, inplace=True)
       
plt.figure(figsize=(15,4))
sns.boxplot(x=ingr_pp['hoeveelheid_pp'])
plt.title('Boxplot van hoeveelheden')
plt.xlabel('hoeveelheid in gram')
plt.grid()
plt.show()

# %% [markdown]
# **Stap 6:** Er zijn nog steeds duidelijke uitbijters. We vervangen alle ingredienten die groter zijn dan 800 gram daarom door 800 gram om de uitbijters voorkomen.
#
# Vervolgens visualiseren we weer de hoeveelheiden in een boxplot.

# %%
gr_dan2 = ingr_pp.copy()[(ingr_pp['hoeveelheid_pp'] > 800)]
for i in gr_dan2['ingredient']:
    ingr_pp['hoeveelheid_pp'].mask(ingr_pp['ingredient'] == i, 800, inplace=True) #Ingredienten > 10k vervangen door 10k

ingr_pp
plt.figure(figsize=(15,4))
sns.boxplot(x=ingr_pp['hoeveelheid_pp'])
plt.title('Boxplot van hoeveelheden')
plt.xlabel('hoeveelheid in gram')
plt.grid()
plt.show()

# %% [markdown]
# **Uitkomst/Conclusie:** In de boxplot is te zien dat er geen uitbijters meer zijn boven de 800 gram. We hebben de data goed opgeschoond.

# %% [markdown]
# ### Hypothesetoets
#
# Hieronder is onze hypothesetoets te zien, we hebben een vermoeden en bijbehoren hypothesen opgesteld met betrekking tot onze extra eis, namelijk: caloriën.

# %% [markdown]
# **Ons vermoeden:**
# De Amerikaanse keuken bevat meer calorieën dan de Hollandse keuken.
#
# @We vermoeden dat de Amerikaanse keuken meer calorieen bevat dan de Hollandse keuken, gebaseerd op de gedachte dat de Amerikaanse keuken vaak wordt gerelateerd aan calorierijke gerechten.
#
# **Onze hypothese:**
# A = de gemiddelde hoeveelheid calorieën in de Amerikaanse keuken
# H = de gemiddelde hoeveelheid calorieën in de Hollandse keuken
#
# H<sub>0</sub>: A <= H vs. H<sub>1</sub>: A > H
#
# **Gekozen significantieniveau**
# a= 0.05

# %%
tags = pd.read_csv('tabellen/data_tags.csv') #inladen datasets
nutri = pd.read_csv('tabellen/data_nutritions.csv') 

#Dataset filteren op de Amerikaanse en Hollandse keuken
amerikaans = tags[(tags['tag'] == 'amerikaans')]
hollands = tags[(tags['tag'] == 'hollands')]

#Tabel maken van ingredienten met de tags, de nutrition energie, en de waarde ervan
nutri_a = nutri[nutri['recipe'].isin(amerikaans['recipe'])]
nutri_h = nutri[nutri['recipe'].isin(hollands['recipe'])] 

#De kcal van elke keuken apart nemen in een lijst
cal_a = nutri_a['value'].loc[nutri_a['nutrition']=='energie'].tolist()
cal_h = nutri_h['value'].loc[nutri_h['nutrition']=='energie'].tolist()  

# h = nutri_h[(nutri_h['nutrition']=='energie')] 
# a= nutri_a[(nutri_a['nutrition']=='energie')]    
# a

# %%
a= [int(i[0:-5]) for i in cal_a]  #Kcal verwijderen zodat het int wordt ipv string
h = [int(i[0:-5]) for i in cal_h]   

df_a = pd.DataFrame({'col':a}) #kcal gegevens omzetten in df per keuken 
df_h = pd.DataFrame({'col':h}) 

df_a['group'] = 'Amerikaans' #labels geven
df_h['group'] = 'Hollands'

combined_df = pd.concat([df_a, df_h]) #df's samenvoegen
sns.boxplot(x='group', y='col', data=combined_df) #visualiseren in boxplot
plt.show()

# %%
ttest_ind(df_a['col'], df_h['col'], equal_var=True) #Ttest van calorien hollands vs amerikaans
# Out:
# TtestResult(statistic=-0.4427550161056866, pvalue=0.6580706089108573, df=750.0)

# %% [markdown]
# **Conclusie**
# Uit de t-test volgt een p-waarde, die groter is dan het gekozen significantieniveau. Dit houdt in dat de nulhypothese behouden blijft, dus ons vermoeden niet klopt.

# %% [markdown]
# ### Regressie-analyse
#
# In ons onderzoek hebben we ons gericht op het verband tussen ingrediënten en de nutriënt vetten. We kozen specifiek voor vetten, omdat deze nutriënt de hoogste caloriën geeft. Aangezien onze extra eis gaat over het tellen van calorieën, is het belangrijk om te onderzoeken wat de rol is van ingrediënten in vetten van de recepten.
#
# We hebben de dataset voorbereid en nu zullen we een regressie analyse uitvoeren. Hierbij zullen we een lineaire regressiemodel opstellen, waarin we vetten als afhankelijke variabelen opnemen en de ingrediënten als onafhankelijke variabelen. De coëfficiënten van dit model zullen worden geschat met behulp van de methode van kleinste kwadraten.

# %% [markdown]
# **Stap 1:** Allereest hebben we de quantity omgezet naar de hoeveelheid voor 1 persoon. Vervolgens hebben we de 10 meest voorkomende ingrediënten in alle recepten bekeken en 3 uitgezocht (tarwebloem, ongezouten roomboter & middelgroot ei) om te kijken hoeveel invloed zij hebben op de hoeveelheid vet in een gerecht.

# %%
nutri_recepten=pd.read_csv('tabellen/data_nutritions.csv')
#ingr_pp2 = ingr_pp.copy()
ingr_pp.ingredient.value_counts()[:10] #De 10 meest voorkomende ingrediënten bekijken
# Out:
# ingredient
# middelgroot ei          1087
# ongezouten roomboter    1006
# tarwebloem               501
# Name: count, dtype: int64

# %%
recepten_ore = ingr_pp[(ingr_pp['ingredient'] == 'tarwebloem') | 
                       (ingr_pp['ingredient'] == 'ongezouten roomboter') | (ingr_pp['ingredient'] == 'middelgroot ei')].copy() 
              #rijen selecteren die overeenkomen met de drie gekozen ingrediënten
recepten_ore
# Out:
#                                    recipe            ingredient  \
# 4                 Kruidnoten in marsepein  ongezouten roomboter
# 8                Kruidnoten met chocodips  ongezouten roomboter
# 12     Pepernotentaart met marsepeinstrik  ongezouten roomboter
# 16     Pepernotentaart met marsepeinstrik        middelgroot ei
# 17     Pepernotentaart met marsepeinstrik            tarwebloem
# ...                                   ...                   ...
# 49395         Paddenstoelentaart met spek        middelgroot ei
# 49444       Italiaans-Amerikaanse lasagne  ongezouten roomboter
# 49446       Italiaans-Amerikaanse lasagne            tarwebloem
# 49496                   Appeljachtschotel  ongezouten roomboter
# 49520                 Kip uit de braadzak  ongezouten roomboter
#
#        hoeveelheid_pp unit  middelgroot ei  tarwebloem  ongezouten roomboter
# 4            3.750000    g               0           0                     1
# 8            1.000000    g               0           0                     1
# 12          35.000000    g               0           0                     1
# 16          18.000000    g               1           0                     0
# 17          20.000000    g               0           1                     0
# ...               ...  ...             ...         ...                   ...
# 49395       40.000000    g               1           0                     0
# 49444       12.500000    g               0           0                     1
# 49446        8.333333    g               0           1                     0
# 49496       12.500000    g               0           0                     1
# 49520        6.250000    g               0           0                     1
#
# [2594 rows x 7 columns]

# %% [markdown]
# **Stap 2:** We voegen tarwebloem, roomboter en middelgroot ei toe aan de dataframe en als het ingredient in het recept voorkomt staat er een 1 in die kolom, daarna de hoeveelheid van die ingredienten vermenigvuldigd met de ingredienten kolommen

# %%
recepten_ore['tarwebloem'] = (recepten_ore['ingredient'] == 'tarwebloem').astype(int)
recepten_ore['ongezouten roomboter'] = (recepten_ore['ingredient'] == 'ongezouten roomboter').astype(int)
recepten_ore['middelgroot ei'] = (recepten_ore['ingredient'] == 'middelgroot ei').astype(int)
recepten_ore
# Out:
#                                    recipe            ingredient  \
# 4                 Kruidnoten in marsepein  ongezouten roomboter
# 8                Kruidnoten met chocodips  ongezouten roomboter
# 12     Pepernotentaart met marsepeinstrik  ongezouten roomboter
# 16     Pepernotentaart met marsepeinstrik        middelgroot ei
# 17     Pepernotentaart met marsepeinstrik            tarwebloem
# ...                                   ...                   ...
# 49395         Paddenstoelentaart met spek        middelgroot ei
# 49444       Italiaans-Amerikaanse lasagne  ongezouten roomboter
# 49446       Italiaans-Amerikaanse lasagne            tarwebloem
# 49496                   Appeljachtschotel  ongezouten roomboter
# 49520                 Kip uit de braadzak  ongezouten roomboter
#
#        hoeveelheid_pp unit  middelgroot ei  tarwebloem  ongezouten roomboter
# 4            3.750000    g               0           0                     1
# 8            1.000000    g               0           0                     1
# 12          35.000000    g               0           0                     1
# 16          18.000000    g               1           0                     0
# 17          20.000000    g               0           1                     0
# ...               ...  ...             ...         ...                   ...
# 49395       40.000000    g               1           0                     0
# 49444       12.500000    g               0           0                     1
# 49446        8.333333    g               0           1                     0
# 49496       12.500000    g               0           0                     1
# 49520        6.250000    g               0           0                     1
#
# [2594 rows x 7 columns]

# %%
recepten_ore['tarwebloem'] = (recepten_ore['tarwebloem'] * recepten_ore['hoeveelheid_pp'])
recepten_ore['ongezouten roomboter'] = (recepten_ore['ongezouten roomboter'] * recepten_ore['hoeveelheid_pp'])
recepten_ore['middelgroot ei'] = (recepten_ore['middelgroot ei'] * recepten_ore['hoeveelheid_pp'])
recepten_ore
# Out:
#                                    recipe            ingredient  \
# 4                 Kruidnoten in marsepein  ongezouten roomboter
# 8                Kruidnoten met chocodips  ongezouten roomboter
# 12     Pepernotentaart met marsepeinstrik  ongezouten roomboter
# 16     Pepernotentaart met marsepeinstrik        middelgroot ei
# 17     Pepernotentaart met marsepeinstrik            tarwebloem
# ...                                   ...                   ...
# 49395         Paddenstoelentaart met spek        middelgroot ei
# 49444       Italiaans-Amerikaanse lasagne  ongezouten roomboter
# 49446       Italiaans-Amerikaanse lasagne            tarwebloem
# 49496                   Appeljachtschotel  ongezouten roomboter
# 49520                 Kip uit de braadzak  ongezouten roomboter
#
#        hoeveelheid_pp unit  middelgroot ei  tarwebloem  ongezouten roomboter
# 4            3.750000    g             0.0    0.000000                  3.75
# 8            1.000000    g             0.0    0.000000                  1.00
# 12          35.000000    g             0.0    0.000000                 35.00
# 16          18.000000    g            18.0    0.000000                  0.00
# 17          20.000000    g             0.0   20.000000                  0.00
# ...               ...  ...             ...         ...                   ...
# 49395       40.000000    g            40.0    0.000000                  0.00
# 49444       12.500000    g             0.0    0.000000                 12.50
# 49446        8.333333    g             0.0    8.333333                  0.00
# 49496       12.500000    g             0.0    0.000000                 12.50
# 49520        6.250000    g             0.0    0.000000                  6.25
#
# [2594 rows x 7 columns]

# %%
agg_functions = {'tarwebloem': 'sum', 'ongezouten roomboter': 'sum', 'middelgroot ei': 'sum'} #rijen die behoren tot één recept samenvoegen
ingrpp_new = recepten_ore.groupby(recepten_ore['recipe']).aggregate(agg_functions).reset_index()
ingrpp_new
# Out:
#                                                  recipe  tarwebloem  \
# 0            'Nasi' met pindasaus en vegan kipstuckjes         0.00
# 1     'Roti' met vegetarische rulstukjes, bonen &amp...        0.00
# 2                              5 spices kerstfiguurtjes        7.00
# 3              Aardappel-bietenrösti met vega-kipragout       12.00
# 4               Aardappel-bloemkoolgratin met hazelnoot        6.25
# ...                                                 ...         ...
# 1795       Zuurkoolstamppot met paddenstoelen en dragon        0.00
# 1796                              Zwarte bonen brownies        0.00
# 1797                   Zweedse gehaktballetjes met room        4.50
# 1798  Zweedse vegaballetjes met aardappel &amp; broc...        6.00
# 1799                                    Îles flottantes        0.00
#
#       ongezouten roomboter  middelgroot ei
# 0                     0.00            60.0
# 1                     0.00            60.0
# 2                     5.00             1.2
# 3                     0.00             0.0
# 4                     6.25             0.0
# ...                    ...             ...
# 1795                 11.25             0.0
# 1796                  0.00            10.0
# 1797                 12.50            15.0
# 1798                  7.50            15.0
# 1799                  0.00            60.0
#
# [1800 rows x 4 columns]

# %%
ingrpp_new.rename(columns={'middelgroot ei': 'middelgroot_ei', 'ongezouten roomboter': 'ongezouten_roomboter'}, inplace=True) 
ingrpp_new
# Out:
#                                                  recipe  tarwebloem  \
# 0            'Nasi' met pindasaus en vegan kipstuckjes         0.00
# 1     'Roti' met vegetarische rulstukjes, bonen &amp...        0.00
# 2                              5 spices kerstfiguurtjes        7.00
# 3              Aardappel-bietenrösti met vega-kipragout       12.00
# 4               Aardappel-bloemkoolgratin met hazelnoot        6.25
# ...                                                 ...         ...
# 1795       Zuurkoolstamppot met paddenstoelen en dragon        0.00
# 1796                              Zwarte bonen brownies        0.00
# 1797                   Zweedse gehaktballetjes met room        4.50
# 1798  Zweedse vegaballetjes met aardappel &amp; broc...        6.00
# 1799                                    Îles flottantes        0.00
#
#       ongezouten_roomboter  middelgroot_ei
# 0                     0.00            60.0
# 1                     0.00            60.0
# 2                     5.00             1.2
# 3                     0.00             0.0
# 4                     6.25             0.0
# ...                    ...             ...
# 1795                 11.25             0.0
# 1796                  0.00            10.0
# 1797                 12.50            15.0
# 1798                  7.50            15.0
# 1799                  0.00            60.0
#
# [1800 rows x 4 columns]

# %% [markdown]
# **Stap 3:** Recepten filteren op recepten die alle drie de ingredienten bevatten; alle ingredienten > 0. En de kolom van de nutrient vet toevoegen door te mergen

# %%
ingr_alles = ingrpp_new[(ingrpp_new['middelgroot_ei'] > 0 ) & (ingrpp_new['ongezouten_roomboter'] > 0 ) & 
                        (ingrpp_new['tarwebloem'] > 0 )] 
ingr_alles
# Out:
#                                                  recipe  tarwebloem  \
# 2                              5 spices kerstfiguurtjes    7.000000
# 16                  Aardappelkoekjes met paddenstoelen    12.500000
# 26                                  Aardbeienfeesttaart   25.000000
# 29                     Aardbeientaartjes met mascarpone   37.500000
# 32       Adjaruli khachapuri (Georgische kaas-eibrood)   162.500000
# ...                                                 ...         ...
# 1763           Zandkoekjes met glazuur 'bloedspetters'    10.416667
# 1765                                       Zebrakoekjes   11.875000
# 1776                Zoete mini-quiches van krentenbrood    2.500000
# 1797                   Zweedse gehaktballetjes met room    4.500000
# 1798  Zweedse vegaballetjes met aardappel &amp; broc...    6.000000
#
#       ongezouten_roomboter  middelgroot_ei
# 2                 5.000000             1.2
# 16                3.333333            10.0
# 26               15.000000             6.0
# 29               31.250000            45.0
# 32               15.000000            60.0
# ...                    ...             ...
# 1763              7.708333             2.5
# 1765              8.333333             2.5
# 1776              7.500000            18.0
# 1797             12.500000            15.0
# 1798              7.500000            15.0
#
# [173 rows x 4 columns]

# %%
recepten_vet = nutri_recepten[(nutri_recepten['nutrition'] == 'vet')] 
recepten_vet
# Out:
#        Unnamed: 0                              recipe nutrition value
# 5               5       Kruidnoten met choco-discodip       vet  12 g
# 13             13             Kruidnoten in marsepein       vet   9 g
# 21             21            Kruidnoten met chocodips       vet  18 g
# 29             29  Pepernotentaart met marsepeinstrik       vet  33 g
# 37             37                           Perencake       vet  11 g
# ...           ...                                 ...       ...   ...
# 40897       58741           Honingwortel met abrikoos       vet  12 g
# 40901       58745    Paddenstoelen en courgettegratin       vet  20 g
# 40906       58750                  Peren-amandelcoupe       vet   1 g
# 40910       58754     Ceviche met sint-jakobsschelpen       vet  13 g
# 40915       58764    Biefstuk met rodewijnsaus en ham       vet  23 g
#
# [5876 rows x 4 columns]

# %%
ingr_plusv = ingr_alles.merge(recepten_vet, how='left', left_on = 'recipe', right_on = 'recipe')
ingr_plusv
# Out:
#                                                 recipe  tarwebloem  \
# 0                             5 spices kerstfiguurtjes    7.000000
# 1                  Aardappelkoekjes met paddenstoelen    12.500000
# 2                                  Aardbeienfeesttaart   25.000000
# 3                     Aardbeientaartjes met mascarpone   37.500000
# 4       Adjaruli khachapuri (Georgische kaas-eibrood)   162.500000
# ..                                                 ...         ...
# 168           Zandkoekjes met glazuur 'bloedspetters'    10.416667
# 169                                       Zebrakoekjes   11.875000
# 170                Zoete mini-quiches van krentenbrood    2.500000
# 171                   Zweedse gehaktballetjes met room    4.500000
# 172  Zweedse vegaballetjes met aardappel &amp; broc...    6.000000
#
#      ongezouten_roomboter  middelgroot_ei  Unnamed: 0 nutrition value
# 0                5.000000             1.2       36642       vet   4 g
# 1                3.333333            10.0         626       vet   9 g
# 2               15.000000             6.0       21204       vet  23 g
# 3               31.250000            45.0       45150       vet  55 g
# 4               15.000000            60.0        3836       vet  73 g
# ..                    ...             ...         ...       ...   ...
# 168              7.708333             2.5         405       vet   7 g
# 169              8.333333             2.5        7040       vet   8 g
# 170              7.500000            18.0       40882       vet  12 g
# 171             12.500000            15.0       34270       vet  45 g
# 172              7.500000            15.0       19025       vet  31 g
#
# [173 rows x 7 columns]

# %% [markdown]
# **Stap 4:** De 'g' achter de hoeveelheid weghalen door de index 0:-1 te nemen

# %%
vetten = ingr_plusv['value'].tolist()
v = [int(i[0:-1]) for i in vetten]    
waarde_vetten = pd.DataFrame({'vetten':v}) 
ingr_alles = ingr_plusv.merge(waarde_vetten, how='left', left_index = True , right_index = True )

ingr_alles.drop(columns=['value','Unnamed: 0','nutrition'], inplace = True)  

ingr_alles
# Out:
#                                                 recipe  tarwebloem  \
# 0                             5 spices kerstfiguurtjes    7.000000
# 1                  Aardappelkoekjes met paddenstoelen    12.500000
# 2                                  Aardbeienfeesttaart   25.000000
# 3                     Aardbeientaartjes met mascarpone   37.500000
# 4       Adjaruli khachapuri (Georgische kaas-eibrood)   162.500000
# ..                                                 ...         ...
# 168           Zandkoekjes met glazuur 'bloedspetters'    10.416667
# 169                                       Zebrakoekjes   11.875000
# 170                Zoete mini-quiches van krentenbrood    2.500000
# 171                   Zweedse gehaktballetjes met room    4.500000
# 172  Zweedse vegaballetjes met aardappel &amp; broc...    6.000000
#
#      ongezouten_roomboter  middelgroot_ei  vetten
# 0                5.000000             1.2       4
# 1                3.333333            10.0       9
# 2               15.000000             6.0      23
# 3               31.250000            45.0      55
# 4               15.000000            60.0      73
# ..                    ...             ...     ...
# 168              7.708333             2.5       7
# 169              8.333333             2.5       8
# 170              7.500000            18.0      12
# 171             12.500000            15.0      45
# 172              7.500000            15.0      31
#
# [173 rows x 5 columns]

# %% [markdown]
# **Stap 5:** Data is nu voorbereid om de lineaire regressiemodel op te stellen. We stellen eerst een heatmap op om de correlaties te bekijken.

# %%
heat = sns.heatmap(ingr_alles.corr(numeric_only = True), cmap="RdYlGn", annot=True)
plt.show()

# %% [markdown]
# **Stap 6:** Scatterplots van elk ingredient tegenover de hoeveelheid vet

# %%
ei = sns.scatterplot(y=ingr_alles.vetten, x=ingr_alles.middelgroot_ei) 
ei
# Out:
# <Axes: xlabel='middelgroot_ei', ylabel='vetten'>

# %%
tarwebloem = sns.scatterplot(y=ingr_alles.vetten, x=ingr_alles.tarwebloem)
tarwebloem
# Out:
# <Axes: xlabel='tarwebloem', ylabel='vetten'>

# %%
boter = sns.scatterplot(y=ingr_alles.vetten, x=ingr_alles.ongezouten_roomboter)
boter
# Out:
# <Axes: xlabel='ongezouten_roomboter', ylabel='vetten'>

# %% [markdown]
# **Stap 7:** Het model opstellen

# %%
model = smf.ols('vetten ~ middelgroot_ei + tarwebloem + ongezouten_roomboter', data=ingr_alles)

# Hierbij schatten we het model
regres = model.fit()

# We printen de samenvatting van de regressieresultaten. 
print(regres.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 vetten   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     70.66
# Date:                Fri, 03 May 2024   Prob (F-statistic):           1.15e-29
# Time:                        08:50:35   Log-Likelihood:                -623.09
# No. Observations:                 173   AIC:                             1254.
# Df Residuals:                     169   BIC:                             1267.
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                6.1621      1.223      5.040      0.000       3.748       8.576
# middelgroot_ei           0.2915      0.048      6.064      0.000       0.197       0.386
# tarwebloem              -0.0018      0.015     -0.118      0.906      -0.031       0.028
# ongezouten_roomboter     0.7610      0.096      7.892      0.000       0.571       0.951
# ==============================================================================
# Omnibus:                       52.117   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.558
# Skew:                           1.148   Prob(JB):                     7.55e-39
# Kurtosis:                       7.368   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sma
sma.qqplot(regres.resid, line='r')
plt.show()

# %% [markdown]
# **Conclusie:** In dit model zijn de coëficientiën van de onafhankelijke variabelen: voor middelgroot_ei: 0.2915, tarwebloem: -0.0018 en ongezouten roomboter: 0.7610. De adjusted R-squared is 0.549, wat betekent dat de onafhankelijke variabelen voor ongeveer 55% de variantie in de afhankelijke variabele verklaart. Daarentegen is de p-waarde voor het coefficiënt van tarwebloem 0.906, hoger dan het significantieniveau 0.05, wat betekent dat tarwebloem mogelijk geen invloed heeft op het niveau van vetten. Verder zie je wel dat de p-waarden van ongezouten boter en middelgroot ei kleiner zijn dan 0.05, wat aangeeft dat ze statistisch significant zijn.
#
# Hiermee kunnen we concluderen dat het middelgrote ei en de ongezouten roomboter een significant effect hebben op het niveau van vetten, terwijl tarwebloem dat niet heeft.

# %% [markdown]
# ### verder in het verslag
#
#     Klasse structuur die overerft van de DataFrame klasse en met de bovenstaande onderdelen.
#     Evaluatie van het aanbevelingsalgoritme met de Precision@10 metriek.
#     De datavekenning met de conclusie.
#     De hypothesetoets met de conclusie.
#     De regressie-analyse met de conclusie.

# %% [markdown]
# ### Reflectie
#
# Dat we geen rekening hebben gehouden met de hoeveelheden van de ingredienten bij de aanbeveling

# %% [markdown]
# ### Bibliografie
